# %% [markdown]
# # 파일 입출력

# %% [markdown]
# ## 1 정형 데이터

# %% [markdown]
# ### 1.1 EXCEL

# %%
import pandas as pd

df = pd.read_excel('rawData.xlsx')
df

# %%
df = pd.read_excel('rawData_sheetplus.xlsx')
df

# %%
df = pd.read_excel('rawData_sheetplus.xlsx', sheet_name="Sheet1") # sheet_name=0
df

# %%
df = pd.read_excel('rawData_sheetplus.xlsx', sheet_name="Sheet2") # sheet_name=1
df

# %%
df = pd.read_excel('rawData_sheetplus.xlsx', sheet_name=None)
df

# %%
type(df)

# %%
type(df['Sheet1'])

# %%
df['Sheet1']

# %%
df['Sheet2']

# %%
df['손실'] = [1000000, 2000000, 1200000, 800000, 3000000, 2400000]
df

# %%
df.to_excel('엑셀_내보내기.xlsx')

# %%
df.to_excel('엑셀_내보내기.xlsx', sheet_name="시트_이름")

# %% [markdown]
# ### 1.2 CSV

# %%
df = pd.read_csv('rawData.csv', encoding="cp949")
df

# %%
df = pd.read_csv('rawData.csv', sep=',', encoding="cp949")
df

# %%
df = pd.read_csv('https://paullab.co.kr/titanic_train.csv')
df

# %%
df = pd.read_csv('rawData.csv', encoding="cp949")
df

# %%
import numpy as np

df['손실'] = np.nan

# %%
df

# %%
df.to_csv('csv 내보내기.csv')

# %%
df.to_csv('csv 내보내기2.csv', sep=' ')

# %%
df = pd.read_csv('csv 내보내기2.csv', sep=' ')
df

# %% [markdown]
# ### 1.3 TXT

# %%
df = pd.read_table("rawData.txt", encoding='cp949', sep=',')
df
# Out:
#    연차    연도        매출       순익  직원수
# 0   1  2015   1000000   100001    1
# 1   2  2016   2000000   200001    2
# 2   3  2017   3000000   300001    4
# 3   4  2018   4000000   400001    8
# 4   5  2019   8000000   800001   16
# 5   6  2020  16000000  1600001   32

# %%
df = pd.read_csv("rawData.txt", encoding='cp949', sep=',')
df
# Out:
#    연차    연도        매출       순익  직원수
# 0   1  2015   1000000   100001    1
# 1   2  2016   2000000   200001    2
# 2   3  2017   3000000   300001    4
# 3   4  2018   4000000   400001    8
# 4   5  2019   8000000   800001   16
# 5   6  2020  16000000  1600001   32

# %%
df['손실'] = 1000
df
# Out:
#    연차    연도        매출       순익  직원수    손실
# 0   1  2015   1000000   100001    1  1000
# 1   2  2016   2000000   200001    2  1000
# 2   3  2017   3000000   300001    4  1000
# 3   4  2018   4000000   400001    8  1000
# 4   5  2019   8000000   800001   16  1000
# 5   6  2020  16000000  1600001   32  1000

# %%
df.to_csv('txt내보내기.txt')

# %%
df.to_string('txt내보내기.txt')

# %%
df.to_markdown('txt내보내기.txt')

# %%
df.to_latex('txt내보내기.txt')

# %% [markdown]
# ### 1.4 불러오기 공통 속성

# %%
df = pd.read_excel('rawData.xlsx')
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
df = pd.read_excel('rawData.xlsx', header=1)
df
# Out:
#    2        2020     4000000  1400000  40
# 0        4     2018  3700000  1370000       38
# 1        6     2016  5300000  2000000       52
# 2        8     2014  7000000  2400000      100
# 3       10     2012  8000000  3000000      320
# 4        5     2017  4600000  1870000       41

# %%
df = pd.read_excel('rawData2.xlsx')
df
# Out:
#   제주도 회사 현황 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0        연차         연도         매출         순익        직원수
# 1         2       2020    4000000    1400000         40
# 2         4       2018    3700000    1370000         38
# 3         6       2016    5300000    2000000         52
# 4         8       2014    7000000    2400000        100
# 5        10       2012    8000000    3000000        320
# 6         5       2017    4600000    1870000         41

# %%
df = pd.read_excel('rawData2.xlsx', header=1)
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
df = pd.read_excel('rawData2.xlsx', header=None)
df
# Out:
#            0     1        2        3    4
# 0  제주도 회사 현황   NaN      NaN      NaN  NaN
# 1         연차    연도       매출       순익  직원수
# 2          2  2020  4000000  1400000   40
# 3          4  2018  3700000  1370000   38
# 4          6  2016  5300000  2000000   52
# 5          8  2014  7000000  2400000  100
# 6         10  2012  8000000  3000000  320
# 7          5  2017  4600000  1870000   41

# %%
df = pd.read_excel('rawData2.xlsx', header=None, names=['연차','연도','매출','순익','직원수'])
df
# Out:
#           연차    연도       매출       순익  직원수
# 0  제주도 회사 현황   NaN      NaN      NaN  NaN
# 1         연차    연도       매출       순익  직원수
# 2          2  2020  4000000  1400000   40
# 3          4  2018  3700000  1370000   38
# 4          6  2016  5300000  2000000   52
# 5          8  2014  7000000  2400000  100
# 6         10  2012  8000000  3000000  320
# 7          5  2017  4600000  1870000   41

# %%
df = pd.read_excel('rawData.xlsx')
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
df = pd.read_excel('rawData.xlsx', index_col='연차') # index_col=0
df
# Out:
#       연도       매출       순익  직원수
# 연차
# 2   2020  4000000  1400000   40
# 4   2018  3700000  1370000   38
# 6   2016  5300000  2000000   52
# 8   2014  7000000  2400000  100
# 10  2012  8000000  3000000  320
# 5   2017  4600000  1870000   41

# %%
df = pd.read_excel('rawData.xlsx', index_col='연도') # index_col=1
df
# Out:
#       연차       매출       순익  직원수
# 연도
# 2020   2  4000000  1400000   40
# 2018   4  3700000  1370000   38
# 2016   6  5300000  2000000   52
# 2014   8  7000000  2400000  100
# 2012  10  8000000  3000000  320
# 2017   5  4600000  1870000   41

# %%
df.loc[[2014]]
# Out:
#       연차       매출       순익  직원수
# 연도
# 2014   8  7000000  2400000  100

# %%
df = pd.read_excel('rawData.xlsx', index_col=None)
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
df = pd.read_excel('rawData.xlsx', usecols=['연차', '연도', '매출']) # usecols=[0, 1, 2]
df
# Out:
#    연차    연도       매출
# 0   2  2020  4000000
# 1   4  2018  3700000
# 2   6  2016  5300000
# 3   8  2014  7000000
# 4  10  2012  8000000
# 5   5  2017  4600000

# %%
df = pd.read_excel('rawData2.xlsx')
df
# Out:
#   제주도 회사 현황 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0        연차         연도         매출         순익        직원수
# 1         2       2020    4000000    1400000         40
# 2         4       2018    3700000    1370000         38
# 3         6       2016    5300000    2000000         52
# 4         8       2014    7000000    2400000        100
# 5        10       2012    8000000    3000000        320
# 6         5       2017    4600000    1870000         41

# %%
df = pd.read_excel('rawData2.xlsx', skiprows=1)
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
df = pd.read_excel('rawData.xlsx', nrows=3)
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52

# %%
df = pd.read_excel('rawData.xlsx', skipfooter=2)
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100

# %% [markdown]
# ### 1.5 내보내기 공통 속성

# %%
df = pd.read_excel('rawData.xlsx')
df
# Out:
#    연차    연도       매출       순익  직원수
# 0   2  2020  4000000  1400000   40
# 1   4  2018  3700000  1370000   38
# 2   6  2016  5300000  2000000   52
# 3   8  2014  7000000  2400000  100
# 4  10  2012  8000000  3000000  320
# 5   5  2017  4600000  1870000   41

# %%
df.to_excel('final.xlsx')

# %%
df.to_excel('final.xlsx', sheet_name='test1', index=True, header=True)

# %%
df.to_excel('final.xlsx', sheet_name='test1', index=None, header=None)

# %% [markdown]
# ## 2 반정형 데이터(JSON, XML, HTML 데이터)

# %% [markdown]
# ### 2.1 JSON

# %%
import pandas as pd

df = pd.read_json('data.json')
df
# Out:
#    id                       productName  price  stockCount  \
# 0   1  버그를 Java라 버그잡는 개리씨 키링 개발자키링 금속키링  12500         100
# 1   2               우당탕탕 라이캣의 실험실 스티커 팩   3500        1000
# 2   3                     딥러닝 개발자 무릎 담요  17500           0
# 3   4                네 개발잡니다 개발자키링 금속키링  13500         100
# 4   5        Hack Your Life 개발자 노트북 파우치  36000         230
# 5   6        [NEW] 위니브 개발자, 캐릭터 스티커팩 2종   5500        1000
# 6   7               제주코딩베이스캠프 코딩 연습장 세트   8000        1000
#
#                    thumbnailImg  \
# 0  asset/img/1/thumbnailImg.jpg
# 1  asset/img/2/thumbnailImg.jpg
# 2  asset/img/3/thumbnailImg.jpg
# 3  asset/img/4/thumbnailImg.jpg
# 4  asset/img/5/thumbnailImg.jpg
# 5  asset/img/6/thumbnailImg.jpg
# 6  asset/img/7/thumbnailImg.jpg
#
#                                               option  discountRate  \
# 0                                                 []             0
# 1                                                 []             0
# ...

# %%
df = pd.read_json('https://test.api.weniv.co.kr/mall')
df
# Out:
#    id                       productName  price  stockCount  \
# 0   1  버그를 Java라 버그잡는 개리씨 키링 개발자키링 금속키링  12500         100
# 1   2               우당탕탕 라이캣의 실험실 스티커 팩   3500        1000
# 2   3                     딥러닝 개발자 무릎 담요  17500           0
# 3   4                네 개발잡니다 개발자키링 금속키링  13500         100
# 4   5        Hack Your Life 개발자 노트북 파우치  36000         230
# 5   6        [NEW] 위니브 개발자, 캐릭터 스티커팩 2종   5500        1000
# 6   7               제주코딩베이스캠프 코딩 연습장 세트   8000        1000
#
#                    thumbnailImg  \
# 0  asset/img/1/thumbnailImg.jpg
# 1  asset/img/2/thumbnailImg.jpg
# 2  asset/img/3/thumbnailImg.jpg
# 3  asset/img/4/thumbnailImg.jpg
# 4  asset/img/5/thumbnailImg.jpg
# 5  asset/img/6/thumbnailImg.jpg
# 6  asset/img/7/thumbnailImg.jpg
#
#                                               option  discountRate  \
# 0                                                 []             0
# 1                                                 []             0
# ...

# %%
df = df.drop(['thumbnailImg', 'detailInfoImage'], axis=1)
df
# Out:
#    id                       productName  price  stockCount  \
# 0   1  버그를 Java라 버그잡는 개리씨 키링 개발자키링 금속키링  12500         100
# 1   2               우당탕탕 라이캣의 실험실 스티커 팩   3500        1000
# 2   3                     딥러닝 개발자 무릎 담요  17500           0
# 3   4                네 개발잡니다 개발자키링 금속키링  13500         100
# 4   5        Hack Your Life 개발자 노트북 파우치  36000         230
# 5   6        [NEW] 위니브 개발자, 캐릭터 스티커팩 2종   5500        1000
# 6   7               제주코딩베이스캠프 코딩 연습장 세트   8000        1000
#
#                                               option  discountRate  \
# 0                                                 []             0
# 1                                                 []             0
# 2                                                 []             0
# 3                                                 []             0
# 4  [{'id': 1, 'optionName': '13인치', 'additionalFe...            19
# 5  [{'id': 1, 'optionName': '위니브 개발자 스티커팩', 'addi...             0
# ...

# %%
df.to_json('json내보내기.json')

# %%
df = pd.read_json('json내보내기.json')
df
# Out:
#    id                       productName  price  stockCount  \
# 0   1  버그를 Java라 버그잡는 개리씨 키링 개발자키링 금속키링  12500         100
# 1   2               우당탕탕 라이캣의 실험실 스티커 팩   3500        1000
# 2   3                     딥러닝 개발자 무릎 담요  17500           0
# 3   4                네 개발잡니다 개발자키링 금속키링  13500         100
# 4   5        Hack Your Life 개발자 노트북 파우치  36000         230
# 5   6        [NEW] 위니브 개발자, 캐릭터 스티커팩 2종   5500        1000
# 6   7               제주코딩베이스캠프 코딩 연습장 세트   8000        1000
#
#                                               option  discountRate  \
# 0                                                 []             0
# 1                                                 []             0
# 2                                                 []             0
# 3                                                 []             0
# 4  [{'id': 1, 'optionName': '13인치', 'additionalFe...            19
# 5  [{'id': 1, 'optionName': '위니브 개발자 스티커팩', 'addi...             0
# ...

# %%
df.to_json('json내보내기.json', indent=4)

# %% [markdown]
# ### 2.2 XML

# %%
df = pd.read_xml('raw_data.xml')
df
# Out:
#      category  id  year    sales   profit  employees
# 0     develop   2  2020  4000000  1400000         40
# 1     develop   4  2018  3700000  1370000         38
# 2     develop   6  2016  5300000  2000000         52
# 3  accounting   8  2014  7000000  2400000        100
# 4  accounting  10  2012  8000000  3000000        320
# 5  accounting   5  2017  4600000  1870000         41

# %%
# https://rss.blog.naver.com/paul-lab.xml

# %%
df = pd.read_xml('https://rss.blog.naver.com/paul-lab.xml')
df
# Out:
#                title                                               link  \
# 0  위니브(Weniv) 공식 블로그  https://blog.naver.com/paul-lab?fromRss=true&t...
#
#           image                            description language   generator  \
# 0  \n\t\t\t\t\t  '기술부터 가치까지' 제주에서 활동하고 있는 주식회사 위니브입니다.       ko  Naver Blog
#
#                            pubDate          item
# 0  Mon, 16 Sep 2024 12:42:19 +0900  \n\t\t\t\t\t

# %%
df = pd.read_xml('https://rss.blog.naver.com/paul-lab.xml', xpath='.//item')
df

# %%
df = pd.read_xml('raw_data.xml')
df
# Out:
#      category  id  year    sales   profit  employees
# 0     develop   2  2020  4000000  1400000         40
# 1     develop   4  2018  3700000  1370000         38
# 2     develop   6  2016  5300000  2000000         52
# 3  accounting   8  2014  7000000  2400000        100
# 4  accounting  10  2012  8000000  3000000        320
# 5  accounting   5  2017  4600000  1870000         41

# %%
df = pd.read_xml('raw_data.xml', xpath='.//row[year>=2015]')
df
# Out:
#      category  id  year    sales   profit  employees
# 0     develop   2  2020  4000000  1400000         40
# 1     develop   4  2018  3700000  1370000         38
# 2     develop   6  2016  5300000  2000000         52
# 3  accounting   5  2017  4600000  1870000         41

# %%
df = pd.read_xml('raw_data.xml', elems_only=True)
df
# Out:
#    id  year    sales   profit  employees
# 0   2  2020  4000000  1400000         40
# 1   4  2018  3700000  1370000         38
# 2   6  2016  5300000  2000000         52
# 3   8  2014  7000000  2400000        100
# 4  10  2012  8000000  3000000        320
# 5   5  2017  4600000  1870000         41

# %%
df = pd.read_xml('raw_data.xml', attrs_only=True)
df
# Out:
#      category
# 0     develop
# 1     develop
# 2     develop
# 3  accounting
# 4  accounting
# 5  accounting

# %%
df.to_xml('xml내보내기.xml')

# %%
df.to_xml('xml내보내기.xml', index=True)

# %%
df.to_xml('xml내보내기.xml', index=True, root_name='blog')

# %%
df.to_xml('xml내보내기.xml', row_name="id")

# %%
df.to_xml('xml내보내기.xml', row_name="hello")

# %%
df.to_xml('xml내보내기.xml', attr_cols=['id', 'year', 'sales'])

# %%
df.columns.tolist()
# Out:
# ['id', 'year', 'sales', 'profit', 'employees']

# %%
df.to_xml('xml내보내기.xml', attr_cols=df.columns.tolist())

# %%
df.to_xml('xml내보내기.xml', elem_cols=['id', 'year', 'sales'])

# %%
df.to_xml('xml내보내기.xml', xml_declaration=False)

# %% [markdown]
# ### 2.3 HTML

# %%
df = pd.read_html('https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%9D%B8%EA%B5%AC')
df
# Out:
# [   Unnamed: 0_level_0    2016           2017          2018          2019  \
#     Unnamed: 0_level_1      인구   인구밀도      인구   인구밀도     인구   인구밀도     인구
#  0                   계   51218    510   51362    512  51607    514  51709
#  1                  서울    9843  16263    9766  16136   9705  16034   9662
#  2                  부산  약3,500   4477  약3,100   4447   3400   4416   3300
#  3                  대구    2461   2786    2458   2782   2450   2773   2432
#  4                  인천    2907   2736    2924   2750   2939   2764   2944
#  5                  광주    1502   2997    1495   2984   1493   2980   1494
#  6                  대전    1536   2848    1528   2832   1518   2813   1509
#  7                  울산    1166   1099    1159   1092   1154   1088   1147
#  8                  세종     234    504     266    571    304    653    331
#  9                  경기   12600   1237   12786   1255  13031   1279  13238
#  10                 강원    1521     90    1521     90   1521     90   1517
# ...

# %%
df[4]
# Out:
#     연도 (년)   추계인구(명)  출생자수(명)  사망자수(명)  자연증가수(명)  조출생률 (1000명당)  \
# 0     1925  12997611   558897   359042    199855           43.0
# 1     1926  13052741   511667   337948    173719           39.2
# 2     1927  13037169   534524   353818    180706           41.0
# 3     1928  13105131   566142   357701    208441           43.2
# 4     1929  13124279   566969   414366    152603           43.2
# 5     1930  13880469   587144   322611    264533           42.3
# 6     1931  13895052   589428   346800    242628           42.4
# 7     1932  14117191   600545   384287    216258           42.5
# 8     1933  14229277   607021   336232    270789           42.7
# 9     1934  14449155   618135   356515    261620           42.8
# 10    1935  15061960   646158   377454    268704           42.9
# 11    1936  15114775   639355   381806    257549           42.3
# 12    1937  15235383   636839   342575    294264           41.8
# 13    1938  15358193   569299   347025    222274           37.1
# ...

# %%
df[4]['출생자수(명)'].sum()
# Out:
# 11480088

# %%
df = pd.read_html('https://paullab.co.kr/stock.html')
df
# Out:
# [        0             1
#  0    시가총액  349조 2,323억원
#  1  시가총액순위      위니브월드 1위
#  2   상장주식수    5969782550,
#                      0                  1
#  0                 현재가       349조 2,323억원
#  1         52주 최고 l 최저  62,800  l  42,300
#  2  배당수익률 l 2040.12  ?              2.42%,
#      0                    1
#  0  매출  22,125,034,978,750원
#  1  비용  19,223,803,154,781원
#  2  순익   2,901,231,823,969원,
#              날짜    종가  전일비    시가    고가    저가      거래량
#  0   2040.10.23  6650   20  6590  6830  6580   398421
#  1   2040.10.22  6630  190  6830  6930  6530   919571
#  2   2040.10.21  6820  390  6440  6890  6360  1678055
#  3   2040.10.18  6430  480  6020  6620  5970  2168857
#  4   2040.10.17  5950   20  6100  6180  5840  1982922
#  5   2040.10.16  5930  290  5620  5930  5350   839434
#  6   2040.10.15  5640  260  5370  5660  5300   702104
#  7   2040.10.14  5380  340  5060  5420  5060   764800
#  8   2040.10.11  5040   60  5100  5170  5020   134558
# ...

# %%
df[0]
# Out:
#         0             1
# 0    시가총액  349조 2,323억원
# 1  시가총액순위      위니브월드 1위
# 2   상장주식수    5969782550

# %%
df[1]
# Out:
#                     0                  1
# 0                 현재가       349조 2,323억원
# 1         52주 최고 l 최저  62,800  l  42,300
# 2  배당수익률 l 2040.12  ?              2.42%

# %%
df[3]
# Out:
#             날짜    종가  전일비    시가    고가    저가      거래량
# 0   2040.10.23  6650   20  6590  6830  6580   398421
# 1   2040.10.22  6630  190  6830  6930  6530   919571
# 2   2040.10.21  6820  390  6440  6890  6360  1678055
# 3   2040.10.18  6430  480  6020  6620  5970  2168857
# 4   2040.10.17  5950   20  6100  6180  5840  1982922
# 5   2040.10.16  5930  290  5620  5930  5350   839434
# 6   2040.10.15  5640  260  5370  5660  5300   702104
# 7   2040.10.14  5380  340  5060  5420  5060   764800
# 8   2040.10.11  5040   60  5100  5170  5020   134558
# 9   2040.10.10  5100   50  5000  5120  4970   288563
# 10  2040.10.08  5050  110  4985  5050  4910   223839
# 11  2040.10.07  4940   70  4990  5110  4905   199580
# 12  2040.10.04  5010   90  4900  5050  4900   188467
# 13  2040.10.02  4920   90  4930  5000  4900   160510
# 14  2040.10.01  5010   10  4950  5050  4950   246145
# 15  2040.09.30  5000   10  5180  5300  4990   705046
# 16  2040.09.27  5010   50  5020  5080  4865   408859
# ...

# %%
df = df[3]
df.head()
df.tail()
# Out:
#             날짜    종가  전일비    시가    고가    저가     거래량
# 15  2040.09.30  5000   10  5180  5300  4990  705046
# 16  2040.09.27  5010   50  5020  5080  4865  408859
# 17  2040.09.26  5060    0  5130  5200  4965  404633
# 18  2040.09.25  5060  270  5280  5320  5040  441923
# 19  2040.09.24  5330   10  5300  5370  5280  211019

# %%
df[['종가']].plot()
# Out:
# <Axes: >
# C:\Users\kwon3\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\kwon3\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\kwon3\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\kwon3\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.to_html('html내보내기.html')

# %% [markdown]
# ## 3 비정형 데이터(이미지, 텍스트)

# %% [markdown]
# ### 3.1 이미지

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
# https://test.api.weniv.co.kr/asset/img/1/thumbnailImg.jpg
img = Image.open('thumbnailImg.jpg')
img
# img.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=510x510>

# %%
img.filename
img.format
img.size #width, height
img.mode #RGB
img.width, img.height
# Out:
# (510, 510)

# %%
resize_img = img.resize((1020, 1020))
resize_img.save('hello.jpg')

# %%
cut_img = img.crop((100, 100, 300, 500))
cut_img.save('cut_img.jpg')

# %%
rotated_img = img.rotate(90)
rotated_img.save('rotated_img.jpg')

# %%
import requests
from io import BytesIO

req = requests.get('https://test.api.weniv.co.kr/asset/img/1/thumbnailImg.jpg')
img = Image.open(BytesIO(req.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=510x510>

# %%
import numpy as np

img_array = np.array(img)
img_array
# Out:
# array([[[244, 244, 246],
#         [244, 244, 246],
#         [244, 244, 246],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [222, 222, 222]],
#
#        [[244, 244, 246],
#         [244, 244, 246],
#         [244, 244, 246],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [222, 222, 222]],
#
#        [[244, 244, 246],
#         [244, 244, 246],
#         [244, 244, 246],
#         ...,
#         [223, 223, 223],
#         [223, 223, 223],
#         [223, 223, 223]],
#
#        ...,
#
#        [[237, 238, 242],
#         [237, 238, 242],
#         [236, 237, 241],
#         ...,
#         [236, 237, 241],
#         [236, 237, 241],
#         [236, 237, 241]],
#
#        [[237, 238, 242],
#         [237, 238, 242],
#         [236, 237, 241],
#         ...,
#         [236, 237, 241],
#         [236, 237, 241],
#         [236, 237, 241]],
#
#        [[237, 238, 242],
#         [237, 238, 242],
#         [236, 237, 241],
# ...

# %%
img_array.shape
# Out:
# (510, 510, 3)

# %%
plt.imshow(img_array)
plt.show()

# %%
test = img_array[:250]
plt.imshow(test)
plt.show()

# %%
test = img_array[:250, :250]
plt.imshow(test)
plt.show()

# %%
test = img_array[300:400, 200:350]
plt.imshow(test)
plt.show()

# %%
test = img_array[300:400:5, 200:350:5]
plt.imshow(test)
plt.show()

# %%
# .convert('L') : grayscale로 바꿔줌
흑백 = img.convert('L')
흑백
# Out:
# <PIL.Image.Image image mode=L size=510x510>

# %%
흑백.save('흑백.jpg')

# %% [markdown]
# ### 3.2 한글 파일

# %%
# %pip install olefile
# %pip install ole-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# ole.open()

# %%
import ole

with ole.open('data.hwp') as f:
    data = f.get_stream('PrvText').read().decode('utf-16le')
    print(data)
# Out:
# 이  력  서
# <인적사항><성          명><홍길동><생  년  월  일><1993년 8월 13일><현    주    소><제주특별자치도 제주시><연    락    처><010-2233-1478><이    메    일><ab8ab@naver.com>
#
# <학력사항><학교명><전공><성적><졸업구분><소재지><건국대학교><컴퓨터공학과><4.1/4.5><졸업><서울>
#
# <자격면허><자격면허증명><시행기관><취득년월><TOEIC><점수><정보처리기사><한국산업인력공단><19.05.22><725점><한국사능력검정 1급><국사편찬위원회><19.08.23>
#
# <교육 / 활동 / 수상><기간><활동 내용><병역사항><군필여부><군필><19.11 ~ 20.03><빅데이터 전략 마에스트로><군별><육군><><><계급><병장><><><복무기간><15.02~16.11>
#
# <컴퓨터 언어   능력 (상/중/하)><R><Python><Javascript><SQL><HTML/CSS><상><중><중><하><하>
#
# 위의 내용은 사실과 틀림없음을 확인합니다.
#
# 2020년 5월 11일 성명 : 홍길동

# %%
data.split('><')[2]
# Out:
# '홍길동'

# %%
splitdata = data.split('><')

# %%
for data in splitdata:
    print(data)
    if data.replace(' ', '') == '성명':
        이름인덱스 = splitdata.index(data) + 1 # 보통 성명 뒤에 이름 나오기 때문에 +1

splitdata[이름인덱스]
# Out:
# 이  력  서
# <인적사항
# 성          명
# 홍길동
# 생  년  월  일
# 1993년 8월 13일
# 현    주    소
# 제주특별자치도 제주시
# 연    락    처
# 010-2233-1478
# 이    메    일
# ab8ab@naver.com>
#
# <학력사항
# 학교명
# 전공
# 성적
# 졸업구분
# 소재지
# 건국대학교
# 컴퓨터공학과
# 4.1/4.5
# 졸업
# 서울>
#
# <자격면허
# 자격면허증명
# 시행기관
# 취득년월
# TOEIC
# 점수
# 정보처리기사
# 한국산업인력공단
# 19.05.22
# 725점
# 한국사능력검정 1급
# 국사편찬위원회
# 19.08.23>
#
# <교육 / 활동 / 수상
# 기간
# 활동 내용
# 병역사항
# 군필여부
# 군필
# 19.11 ~ 20.03
# 빅데이터 전략 마에스트로
# 군별
# 육군
#
#
# 계급
# 병장
#
#
# 복무기간
# 15.02~16.11>
#
# <컴퓨터 언어   능력 (상/중/하)
# R
# Python
# Javascript
# SQL
# HTML/CSS
# 상
# 중
# 중
# 하
# 하>
#
# 위의 내용은 사실과 틀림없음을 확인합니다.
#
# 2020년 5월 11일 성명 : 홍길동
# '홍길동'
