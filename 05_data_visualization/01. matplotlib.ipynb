# %% [markdown]
# # 데이터 시각화
# - 데이터 시각화는 복잡하고 방대한 양의 데이터를 시각적인 요소를 활용하여 쉽고 빠르게 이해할 수 있도록 표현하는 과정
# - 다양한 시각적 도구를 사용하여 데이터의 특징, 추세, 패턴을 한눈에 파악

# %% [markdown]
# ![20240822_112716.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 데이터 시각화를 하는 이유
# - 복잡한 데이터를 간단하게
#     - 숫자로만 구성된 데이터는 이해하기 어렵지만, 시각적으로 표현하면 누구나 쉽게 파악
# - 데이터 간의 관계 파악
#     - 시각화를 통해 데이터 간의 관계를 직관적으로 확인
# - 숨겨진 정보 발견
#     - 숫자로만 분석하기 어려운 데이터 속에 숨겨진 패턴이나 이상치를 발견
# - 효과적인 의사소통
#     - 데이터를 시각화하면 복잡한 분석 결과를 간결하게 전달하고, 다른 사람들과 쉽게 공유

# %% [markdown]
# ## 데이터 시각화의 활용 분야
# - 비즈니스
#     - 매출 분석, 고객 행동 분석, 마케팅 전략 수립 등
# - 과학
#     - 연구 결과 시각화, 데이터 분석
# - 금융
#     - 주식 시장 분석, 투자 포트폴리오 관리
# - 의료
#     - 환자 데이터 분석, 질병 진단
# - 사회과학
#     - 사회 현상 분석, 설문 조사 결과 시각화

# %% [markdown]
# ## 데이터 시각화 도구
# - Tableau
#     - 데이터를 탐색하고 시각화하는 데 특화된 도구
# - Python (Matplotlib, Seaborn)
#     - 프로그래밍 방식으로 정교한 시각화를 구현
# - 엑셀
#     - 간단한 차트와 그래프를 생성하는 데 사용
# - 파워 BI
#     - 다양한 시각화 기능을 제공하며, 대규모 데이터 분석에 적합

# %% [markdown]
# # Matplotlib
# - 파이썬 데이터 시각화의 기본 도구
# - 파이썬에서 가장 널리 사용되는 데이터 시각화 라이브러리 중 하나
# - 간단한 선 그래프부터 복잡한 맞춤형 시각화까지 다양한 형태의 그래프를 생성
#
#
#
#
# - 설치
# ```bash
# pip install matplotlib
# ```

# %% [markdown]
# ## Matplotlib의 주요 특징
# - 선 그래프, 막대 그래프, 산점도, 히스토그램, 파이 차트 등 다양한 종류의 플롯을 지원
# - 플롯의 색상, 선 스타일, 마커, 레이블, 제목 등을 자유롭게 변경하여 원하는 시각화를 만들수 있음
# - Jupyter Notebook 환경에서 바로 시각화 결과를 확인 가능

# %% [markdown]
# ## Matplotlib의 장단점
# - 장점
#     - 유연성
#     > 다양한 차트 종류와 커스터마이징 옵션을 제공하여 복잡한 시각화도 구현 가능
#     - 확장성
#     > 다른 라이브러리와의 연동이 용이하여 다양한 방식으로 활용
#     - 오픈 소스
#     > 무료로 사용할 수 있으며, 활발한 커뮤니티를 통해 많은 정보를 얻을 수 있음
# - 단점
#     - 복잡성
#     > 기본적인 사용법은 간단하지만, 복잡한 시각화를 하려면 많은 코드를 작성해야 함
#     - 학습 곡선
#     > 다양한 기능을 익히는 데 시간이 걸릴 수 있음

# %% [markdown]
# ## 언제 Matplotlib을 사용해야 할까?
# - 간단한 시각화
#     - 선 그래프, 막대 그래프 등 기본적인 시각화가 필요할 때
# - 맞춤형 시각화
#     - 다른 시각화 라이브러리로는 구현하기 어려운 복잡한 시각화가 필요할 때
# - 다른 라이브러리와의 연동
#     - 다른 시각화 라이브러리와 함께 사용하여 더욱 강력한 시각화를 구현하고 싶을 때

# %% [markdown]
# ## matplotlib 이용할때 한글 깨짐 현상 해결방법

# %% [markdown]
# ```python
# # 윈도우 pc 에서의 방법
# import matplotlib.pyplot as plt
# plt.rcParams['font.family'] ='Malgun Gothic'
# plt.rcParams['axes.unicode_minus'] =False
#
# # 코랩에서의 방법
# import matplotlib
# from matplotlib import font_manager
#
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
#
# fontpaths = ["/usr/share/fonts/truetype/nanum/"]
# font_files = font_manager.findSystemFonts(fontpaths=fontpaths)
#
# for ff in font_files:
#     font_manager.fontManager.addfont(ff)
#
# matplotlib.rc('font', family="NanumGothic")
# matplotlib.rcParams['axes.unicode_minus'] = False
# ```

# %%
import matplotlib
from matplotlib import font_manager

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv

fontpaths = ["/usr/share/fonts/truetype/nanum/"]
font_files = font_manager.findSystemFonts(fontpaths=fontpaths)

for ff in font_files:
    font_manager.fontManager.addfont(ff)

matplotlib.rc('font', family="NanumGothic")
matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (16.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123620 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# ## figure와 axes 객체
# - figure
#     - 전체 그림판
#     - Figure는 1개 이상의 그래프들을 담는 틀이나 창을 의미
#     - 우리가 최종적으로 보게 되는 시각화 그래프들의 전체를 감싸는 가장 바깥쪽 영역
# - axes
#     - Axes는 Figure 내부에 존재하는 하나의 그래프 그리는 공간
#     - 실제로 데이터를 시각화하여 그래프, 차트 등을 그리는 영역

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.axes()
plt.show() # 생략 가능, 명시 권장

# %% [markdown]
# ## 단일 그래프

# %% [markdown]
# - plot 함수
#     - line plot 을 그려주는 함수

# %%
plt.plot(np.arange(2, 7))
plt.show()

# %% [markdown]
# ## 다중 그래프
# - 1개의 axes 안에 여러 개의 그래프 출력

# %%
plt.figure(figsize=[15, 5])
plt.plot(np.arange(5))
plt.plot(np.arange(2, 7))
plt.show()

# %% [markdown]
# ## subplots 함수를 이용해서 axes 여러 개 그리기

# %%
fig, ax = plt.subplots(2,2,figsize=[15,5])
ax[0,0].plot(np.arange(5))
ax[0,1].plot(np.arange(2, 7))
ax[1,0].plot(np.arange(5))
ax[1,1].plot(np.arange(2, 7))
plt.show()

# %% [markdown]
# - 다른 방식

# %%
plt.figure(figsize=[15,5])

plt.subplot(2, 2, 1)
plt.plot(np.arange(5))

plt.subplot(2, 2, 2)
plt.plot(np.arange(5))
plt.plot(np.arange(2, 7))

plt.subplot(223) # ,(콤마) 생략가능
plt.plot(np.arange(5))

plt.subplot(224)
plt.plot(np.arange(5))

plt.show()

# %% [markdown]
# ## 타이틀 설정하기

# %%
fig, ax = plt.subplots(1, 2, figsize=[15, 5])
fig.suptitle('제목')

x = np.arange(10)
ax[0].plot(x, np.exp(x))
ax[0].set_title("ax1 제목")

x = np.arange(1, 1000)
ax[1].plot(x, np.log(x))
ax[1].set_title("ax2 제목")

plt.show()

# %%
x = np.arange(1, 1000)
y = np.log(x)

# %% [markdown]
# ## x, y 축에 이름 넣기

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel('x축 이름')
ax.set_ylabel('y축 이름', rotation=0, labelpad=20)
plt.show()

# %% [markdown]
# ## 눈금 회전하기

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# ## 눈금 지정하기

# %%
fig, ax = plt.subplots(figsize=[15,10])
ax.plot(np.arange(50))
ax.set_xticks(np.arange(50))
ax.set_yticks(np.arange(50))
plt.show()

# %% [markdown]
# ## marker, line style, line color 변경하기

# %%
fig, ax = plt.subplots(2, 2, figsize=[15,5])
ax[0,0].plot(np.exp(range(0, 10)), marker="o")
ax[0,1].plot(np.exp(range(0, 10)), marker="v", color="r", linestyle="--")
ax[1,0].plot(np.exp(range(0, 10)), marker="x", color="black", linestyle="")
ax[1,1].plot(np.exp(range(0, 10)), marker="^", color="#D1B2FF", linestyle=":")
plt.show()

# %% [markdown]
# ## 범례 표시하기

# %%
fig, ax = plt.subplots()

y = np.arange(10)
ax.plot(y)
ax.plot(y**2, alpha=0.2)
ax.legend(["Y", "Y^2"], loc=[0.03, 0.85])

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = "/content/drive/MyDrive/data/"
df = pd.read_csv(f"{DATA_PATH}campaign_train.csv")
df.head()
# Out:
#         ID  출생연도 고객_교육수준 고객_결혼여부    고객_소득  고객_자녀수  고객_청소년수     고객_가입날짜  \
# 0  train_0  1969      박사      기혼  30396.0       1        0  2014-04-30
# 1  train_1  1967      박사      기혼  36947.0       1        1  2012-08-07
# 2  train_2  1949      석사      사별  47570.0       1        1  2013-05-29
# 3  train_3  1976      석사      기혼  81929.0       1        0  2012-09-29
# 4  train_4  1982      고졸      기혼  57937.0       0        1  2014-02-16
#
#    고객_최신구매일_경과기간  고객_와인_구매금액  ...  고객_카탈로그_통한_구매횟수  고객_매장방문_구매횟수  \
# 0             22          15  ...                1             2
# 1             49          88  ...                0             4
# 2              3          67  ...                2             2
# 3             60        1486  ...                4            10
# 4             56         261  ...                4             9
#
#    고객_지난달_회사사이트_방문횟수  캠페인1_수락여부  캠페인2_수락여부  캠페인3_수락여부  캠페인4_수락여부  캠페인5_수락여부  \
# 0                  7          0          0          1          0          0
# 1                  9          0          0          0          0          0
# 2                  7          0          0          0          0          0
# 3                  6          0          0          1          0          1
# 4                  3          0          0          0          0          0
#
#    불만제기  target
# 0     0       1
# 1     0       0
# 2     0       1
# 3     0       1
# 4     0       0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Line plot
# - 일반적으로 시간을 x축에 두고, y축에 데이터의 추이를 볼 때 사용
# - x값의 변화에 따른 y값의 변화에 대한 흐름
# - 예시
#     - 특정 기간 동안의 주가 변동
#     - 기온, 강수량 변화
#     - 웹사이트의 방문자수 추이
#     - 월별, 분기별, 연도별 매출액 변화
#     - 과거 데이터를 바탕으로 미래를 예측하는 그래프를 그릴 때

# %%
# 연도-월별 가입자 추이
tmp = df["고객_가입날짜"].str[:7].value_counts().reset_index().sort_values("고객_가입날짜")
tmp
# Out:
#     고객_가입날짜  count
# 23  2012-07      1
# 0   2012-08     75
# 7   2012-09     61
# 17  2012-10     55
# 6   2012-11     63
# 13  2012-12     57
# 2   2013-01     65
# 9   2013-02     60
# 8   2013-03     61
# 14  2013-04     56
# 5   2013-05     63
# 16  2013-06     55
# 15  2013-07     55
# 10  2013-08     59
# 12  2013-09     58
# 4   2013-10     64
# 20  2013-11     49
# 18  2013-12     54
# 19  2014-01     54
# 21  2014-02     47
# 1   2014-03     66
# 11  2014-04     59
# 3   2014-05     65
# 22  2014-06     42

# %%
fig, ax = plt.subplots()
ax.plot(tmp["고객_가입날짜"], tmp["count"])
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
# 고객의 가입연도별 고객_와인_구매금액의 매출 추이
df["고객_가입연도"] = df["고객_가입날짜"].str[:4]
tmp = df.groupby("고객_가입연도")["고객_와인_구매금액"].sum()
fig, ax = plt.subplots()
ax.plot(tmp.index, tmp)
plt.show()

# %%
# 고객의 가입연도별 고객_와인_구매금액의 매출 추이
tmp = df.groupby(df["고객_가입날짜"].str[:4]).sum()["고객_와인_구매금액"].reset_index()
fig, ax = plt.subplots()
ax.plot(tmp["고객_가입날짜"], tmp["고객_와인_구매금액"])
plt.show()

# %%
# 결혼 여부에 따른 고객 와인 구매 금액
tmp = df.groupby("고객_결혼여부")["고객_와인_구매금액"].sum()
fig, ax = plt.subplots()
ax.plot(tmp.index, tmp)
plt.show()

# %% [markdown]
# # Scatter plot
# - 산점도
# - 두 수치형 변수 사이의 관계를 시각화
# - 예시
#     - 키와 몸무게의 관계, 나이와 혈압의 관계
#     - 소비와 지출의 관계, 주가와 이자율의 관계

# %%
df.columns
# Out:
# Index(['ID', '출생연도', '고객_교육수준', '고객_결혼여부', '고객_소득', '고객_자녀수', '고객_청소년수',
#        '고객_가입날짜', '고객_최신구매일_경과기간', '고객_와인_구매금액', '고객_과일_구매금액', '고객_육류_구매금액',
#        '고객_생선_구매금액', '고객_사탕_구매금액', '고객_골드_구매금액', '고객_할인품목_구매횟수',
#        '고객_회사사이트_통한_구매횟수', '고객_카탈로그_통한_구매횟수', '고객_매장방문_구매횟수',
#        '고객_지난달_회사사이트_방문횟수', '캠페인1_수락여부', '캠페인2_수락여부', '캠페인3_수락여부', '캠페인4_수락여부',
#        '캠페인5_수락여부', '불만제기', 'target', '고객_가입연도'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
ax.scatter(df["고객_와인_구매금액"], df["고객_육류_구매금액"])
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(df["고객_와인_구매금액"], df["고객_육류_구매금액"], s=df["고객_골드_구매금액"]) # 고객_골드_구매금액에 따라 포인터 크기 조절
plt.show()

# %%
fig, ax = plt.subplots()
ax_obj = ax.scatter(df["고객_와인_구매금액"], df["고객_육류_구매금액"], c=df["고객_과일_구매금액"], s=df["고객_골드_구매금액"]) # 고객_과일_구매금액에 따라 포인터 색상 조절
plt.colorbar(ax_obj)
plt.show()

# %%
df["고객_와인_구매금액"].corr(df["고객_육류_구매금액"])
# Out:
# 0.5510796458573771

# %% [markdown]
# # Bar chart
# - 범주형 변수에 대한 집계를 시각화
# - 범주의 빈도수를 비교할 때 사용
# - 예시
#     - 연령대별 인구수, 지역별 인구수
#     - 상품별 구매빈도
#     - 과목별 평균점수 비교

# %%
# 고객_교육수준별 가입자 수
tmp = df["고객_교육수준"].value_counts()
tmp
# Out:
# 고객_교육수준
# 학사       647
# 박사       306
# 석사       224
# 고졸       119
# 초졸_중졸     35
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
ax.bar(tmp.index, tmp)
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(tmp.index, tmp)
# ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
# 2013년도 부터 가입한 고객들에 대하여 고객_교육수준별 고객_매장방문_구매횟수 합을 bar plot 으로 시각화
mask = df["고객_가입연도"] >= "2013"
df2 = df[mask] # df.loc[mask]
tmp = df2.groupby("고객_교육수준")["고객_매장방문_구매횟수"].sum()
tmp
# Out:
# 고객_교육수준
# 고졸        453
# 박사       1301
# 석사       1056
# 초졸_중졸      65
# 학사       2871
# Name: 고객_매장방문_구매횟수, dtype: int64

# %%
ax_params = {
    "x": tmp.index,
    "height": tmp
}

fig, ax = plt.subplots()
ax.bar(**ax_params, color=["#FF0000", "blue", "yellow", "pink", "orange"])
plt.show()

# %% [markdown]
# # Pie 차트(원 그래프)
# - 전체에서 각 범주들의 부분을 비율로 표현한 그래프
# - 전체를 구성하는 부분들의 비율을 한 눈에 보여주는 데 효과적

# %%
tmp = tmp.reset_index()
tmp
# Out:
#   고객_교육수준  고객_매장방문_구매횟수
# 0      고졸           453
# 1      박사          1301
# 2      석사          1056
# 3   초졸_중졸            65
# 4      학사          2871

# %%
# 고객_교육수준별 고객_매장방문_구매횟수 파이차트
fig, ax = plt.subplots()
ax.pie(
    tmp["고객_매장방문_구매횟수"],
    labels=tmp["고객_교육수준"],
    autopct="%.2f%%",
    startangle=90,
    explode=[0.1, 0.1, 0.1, 0.4, 0.1],
    counterclock=False
)
plt.show()

# %% [markdown]
# # histogram
# - 수치형 데이터의 구간의 빈도수를 볼 때 사용
# - 수치형 데이터의 분포를 확인할 때 사용
# - 예시
#     - 시험 점수 분포
#     - 소득 분포

# %%
np.random.seed(42)
arr = np.random.randn(1000) # 평균이 0 이고 분산이 1 인 정규분포의 랜덤값 반환
fig, ax = plt.subplots()
ax.hist(arr)
plt.show()

# %%
df.columns
# Out:
# Index(['ID', '출생연도', '고객_교육수준', '고객_결혼여부', '고객_소득', '고객_자녀수', '고객_청소년수',
#        '고객_가입날짜', '고객_최신구매일_경과기간', '고객_와인_구매금액', '고객_과일_구매금액', '고객_육류_구매금액',
#        '고객_생선_구매금액', '고객_사탕_구매금액', '고객_골드_구매금액', '고객_할인품목_구매횟수',
#        '고객_회사사이트_통한_구매횟수', '고객_카탈로그_통한_구매횟수', '고객_매장방문_구매횟수',
#        '고객_지난달_회사사이트_방문횟수', '캠페인1_수락여부', '캠페인2_수락여부', '캠페인3_수락여부', '캠페인4_수락여부',
#        '캠페인5_수락여부', '불만제기', 'target', '고객_가입연도'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
ax.hist(df["고객_와인_구매금액"])
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df["고객_와인_구매금액"], bins=30)
plt.show()

# %% [markdown]
# # Box Plot
# - 4분위수를 기준으로 데이터의 최대, 최소, Q1(25%지점), Q2(50%지점), Q3(75%지점) 등 통계적인 부분들을 손쉽게 시각화
# - 이상치도 빠르게 판단이 가능
# - IQR(Inter Quantile Range) : Q3 - Q1 , 3사분위수와 1사분위수의 차이
# - Box Plot에서 최소값: Q1 - IQR * 1.5
# - Box Plot에서 최대값: Q3 + IQR * 1.5
# - Box Plot에서 최소값과 최대값을 벗어나면 이상치로 해석함

# %% [markdown]
# ![다운로드.gif](data:image/gif;base64,...)

# %%
col_name = "고객_골드_구매금액"

# %%
q = df[col_name].quantile(np.arange(0, 1.1, 0.25)).to_numpy()
q
# Out:
# array([  0.,   8.,  24.,  54., 362.])

# %%
IQR = q[3] - q[1]
box_min = q[1] - 1.5 * IQR # 박스플롯 최소값
box_max = q[3] + 1.5 * IQR # 박스플롯 최대값

box_min, box_max
# Out:
# (-61.0, 123.0)

# %%
ticks = np.concatenate([
    q,
    [box_min, box_max]
])
ticks
# Out:
# array([  0.,   8.,  24.,  54., 362., -61., 123.])

# %%
fig, ax = plt.subplots()
ax.boxplot(df[col_name])
ax.set_yticks(ticks)
plt.show()

# %%
fig, ax = plt.subplots()
ax.boxplot(df[col_name], vert=False)
ax.set_xticks(ticks)
plt.show()

# %% [markdown]
# # heatmap

# %%
corr_df = df.corr(numeric_only=True)
corr_df
# Out:
#                        출생연도     고객_소득    고객_자녀수   고객_청소년수  고객_최신구매일_경과기간  \
# 출생연도               1.000000 -0.162463  0.220321 -0.376377      -0.044871
# 고객_소득             -0.162463  1.000000 -0.401297  0.031131       0.016253
# 고객_자녀수             0.220321 -0.401297  1.000000 -0.045772      -0.026695
# 고객_청소년수           -0.376377  0.031131 -0.045772  1.000000       0.037687
# 고객_최신구매일_경과기간     -0.044871  0.016253 -0.026695  0.037687       1.000000
# 고객_와인_구매금액        -0.176704  0.521059 -0.501840  0.022864       0.035986
# 고객_과일_구매금액        -0.012610  0.386605 -0.384516 -0.163320       0.017510
# 고객_육류_구매금액        -0.025353  0.519590 -0.437287 -0.249935       0.065533
# 고객_생선_구매금액        -0.040031  0.406880 -0.407574 -0.196938       0.026876
# 고객_사탕_구매금액        -0.028913  0.391710 -0.380333 -0.150414       0.045620
# 고객_골드_구매금액        -0.043882  0.286888 -0.340541 -0.009898       0.029555
# 고객_할인품목_구매횟수      -0.055471 -0.093636  0.222372  0.366050      -0.002334
# 고객_회사사이트_통한_구매횟수  -0.153851  0.346126 -0.371250  0.152878      -0.001982
# 고객_카탈로그_통한_구매횟수   -0.136958  0.517332 -0.509159 -0.094834       0.061252
# 고객_매장방문_구매횟수      -0.137908  0.473119 -0.511506  0.067614       0.030643
# 고객_지난달_회사사이트_방문횟수  0.110896 -0.508399  0.459881  0.121220      -0.027738
# 캠페인1_수락여부          0.002306  0.253082 -0.179512 -0.124328      -0.022053
# 캠페인2_수락여부          0.009248  0.092668 -0.094503 -0.019952       0.003678
# 캠페인3_수락여부          0.097742 -0.026601  0.034420 -0.068366      -0.070337
# 캠페인4_수락여부         -0.067236  0.162966 -0.170463  0.054153       0.041600
# 캠페인5_수락여부          0.019762  0.307884 -0.200869 -0.191886       0.000733
# 불만제기              -0.058660 -0.036038  0.058490 -0.008358       0.014984
# target             0.037969  0.108167 -0.066036 -0.159804      -0.199516
#
#                    고객_와인_구매금액  고객_과일_구매금액  고객_육류_구매금액  고객_생선_구매금액  고객_사탕_구매금액  \
# 출생연도                -0.176704   -0.012610   -0.025353   -0.040031   -0.028913
# 고객_소득                0.521059    0.386605    0.519590    0.406880    0.391710
# 고객_자녀수              -0.501840   -0.384516   -0.437287   -0.407574   -0.380333
# 고객_청소년수              0.022864   -0.163320   -0.249935   -0.196938   -0.150414
# 고객_최신구매일_경과기간        0.035986    0.017510    0.065533    0.026876    0.045620
# 고객_와인_구매금액           1.000000    0.377833    0.551080    0.379207    0.349745
# 고객_과일_구매금액           0.377833    1.000000    0.544655    0.621659    0.532850
# 고객_육류_구매금액           0.551080    0.544655    1.000000    0.586093    0.522984
# 고객_생선_구매금액           0.379207    0.621659    0.586093    1.000000    0.561411
# 고객_사탕_구매금액           0.349745    0.532850    0.522984    0.561411    1.000000
# 고객_골드_구매금액           0.354091    0.395963    0.334189    0.427612    0.375579
# 고객_할인품목_구매횟수        -0.000522   -0.116608   -0.110122   -0.155419   -0.130576
# 고객_회사사이트_통한_구매횟수     0.529154    0.293360    0.278155    0.276316    0.350210
# 고객_카탈로그_통한_구매횟수      0.632972    0.497700    0.714217    0.554766    0.472643
# 고객_매장방문_구매횟수         0.640122    0.462750    0.473236    0.471050    0.426724
# 고객_지난달_회사사이트_방문횟수   -0.312494   -0.402956   -0.532330   -0.455090   -0.414640
# 캠페인1_수락여부            0.369822    0.193564    0.295560    0.260745    0.226852
# 캠페인2_수락여부            0.252085   -0.012293    0.062231    0.003744    0.020305
# 캠페인3_수락여부            0.059041    0.019029    0.020801   -0.030276   -0.013459
# 캠페인4_수락여부            0.377642    0.024702    0.131525    0.019484    0.034159
# 캠페인5_수락여부            0.463191    0.219497    0.383015    0.214396    0.257346
# 불만제기                -0.044726   -0.015488   -0.034250   -0.027782   -0.041592
# target               0.216508    0.153471    0.215211    0.118879    0.100953
#
#                    ...  고객_카탈로그_통한_구매횟수  고객_매장방문_구매횟수  고객_지난달_회사사이트_방문횟수  \
# 출생연도               ...        -0.136958     -0.137908           0.110896
# 고객_소득              ...         0.517332      0.473119          -0.508399
# 고객_자녀수             ...        -0.509159     -0.511506           0.459881
# 고객_청소년수            ...        -0.094834      0.067614           0.121220
# 고객_최신구매일_경과기간      ...         0.061252      0.030643          -0.027738
# 고객_와인_구매금액         ...         0.632972      0.640122          -0.312494
# 고객_과일_구매금액         ...         0.497700      0.462750          -0.402956
# 고객_육류_구매금액         ...         0.714217      0.473236          -0.532330
# 고객_생선_구매금액         ...         0.554766      0.471050          -0.455090
# 고객_사탕_구매금액         ...         0.472643      0.426724          -0.414640
# 고객_골드_구매금액         ...         0.434720      0.377591          -0.264987
# 고객_할인품목_구매횟수       ...        -0.010586      0.055131           0.367430
# 고객_회사사이트_통한_구매횟수   ...         0.360624      0.480764          -0.089942
# 고객_카탈로그_통한_구매횟수    ...         1.000000      0.522109          -0.532170
# 고객_매장방문_구매횟수       ...         0.522109      1.000000          -0.425594
# 고객_지난달_회사사이트_방문횟수  ...        -0.532170     -0.425594           1.000000
# 캠페인1_수락여부          ...         0.316824      0.180804          -0.179857
# 캠페인2_수락여부          ...         0.121533      0.082369          -0.020668
# 캠페인3_수락여부          ...         0.090578     -0.070319           0.075312
# 캠페인4_수락여부          ...         0.148235      0.187916          -0.045743
# 캠페인5_수락여부          ...         0.342327      0.223657          -0.263398
# 불만제기               ...        -0.031800     -0.031350           0.020863
# target             ...         0.208160      0.001002          -0.006132
#
#                    캠페인1_수락여부  캠페인2_수락여부  캠페인3_수락여부  캠페인4_수락여부  캠페인5_수락여부  \
# 출생연도                0.002306   0.009248   0.097742  -0.067236   0.019762
# 고객_소득               0.253082   0.092668  -0.026601   0.162966   0.307884
# 고객_자녀수             -0.179512  -0.094503   0.034420  -0.170463  -0.200869
# 고객_청소년수            -0.124328  -0.019952  -0.068366   0.054153  -0.191886
# 고객_최신구매일_경과기간      -0.022053   0.003678  -0.070337   0.041600   0.000733
# 고객_와인_구매금액          0.369822   0.252085   0.059041   0.377642   0.463191
# 고객_과일_구매금액          0.193564  -0.012293   0.019029   0.024702   0.219497
# 고객_육류_구매금액          0.295560   0.062231   0.020801   0.131525   0.383015
# 고객_생선_구매금액          0.260745   0.003744  -0.030276   0.019484   0.214396
# 고객_사탕_구매금액          0.226852   0.020305  -0.013459   0.034159   0.257346
# 고객_골드_구매금액          0.156795   0.011775   0.113596  -0.004331   0.136335
# 고객_할인품목_구매횟수       -0.109251  -0.050570  -0.020150   0.001416  -0.187825
# 고객_회사사이트_통한_구매횟수    0.145247   0.036893   0.062580   0.127636   0.139416
# 고객_카탈로그_통한_구매횟수     0.316824   0.121533   0.090578   0.148235   0.342327
# 고객_매장방문_구매횟수        0.180804   0.082369  -0.070319   0.187916   0.223657
# 고객_지난달_회사사이트_방문횟수  -0.179857  -0.020668   0.075312  -0.045743  -0.263398
# 캠페인1_수락여부           1.000000   0.209402   0.068288   0.233983   0.396904
# 캠페인2_수락여부           0.209402   1.000000   0.042478   0.326762   0.225721
# 캠페인3_수락여부           0.068288   0.042478   1.000000  -0.080795   0.070973
# 캠페인4_수락여부           0.233983   0.326762  -0.080795   1.000000   0.242487
# 캠페인5_수락여부           0.396904   0.225721   0.070973   0.242487   1.000000
# 불만제기               -0.026476  -0.011186   0.000106  -0.027716  -0.027564
# target              0.289446   0.158455   0.288210   0.140044   0.319645
#
#                        불만제기    target
# 출생연도              -0.058660  0.037969
# 고객_소득             -0.036038  0.108167
# 고객_자녀수             0.058490 -0.066036
# 고객_청소년수           -0.008358 -0.159804
# 고객_최신구매일_경과기간      0.014984 -0.199516
# 고객_와인_구매금액        -0.044726  0.216508
# 고객_과일_구매금액        -0.015488  0.153471
# 고객_육류_구매금액        -0.034250  0.215211
# 고객_생선_구매금액        -0.027782  0.118879
# 고객_사탕_구매금액        -0.041592  0.100953
# 고객_골드_구매금액        -0.022414  0.093170
# 고객_할인품목_구매횟수       0.019582 -0.028024
# 고객_회사사이트_통한_구매횟수  -0.022931  0.134267
# 고객_카탈로그_통한_구매횟수   -0.031800  0.208160
# 고객_매장방문_구매횟수      -0.031350  0.001002
# 고객_지난달_회사사이트_방문횟수  0.020863 -0.006132
# 캠페인1_수락여부         -0.026476  0.289446
# 캠페인2_수락여부         -0.011186  0.158455
# 캠페인3_수락여부          0.000106  0.288210
# 캠페인4_수락여부         -0.027716  0.140044
# 캠페인5_수락여부         -0.027564  0.319645
# 불만제기               1.000000  0.001399
# target             0.001399  1.000000
#
# [23 rows x 23 columns]

# %%
cols = corr_df.columns.tolist()
len(cols)
# Out:
# 23

# %%
fig, ax = plt.subplots(figsize=[10,10])
ax_obj = ax.matshow(corr_df)
ax.set_xticks(np.arange(len(cols)), cols)
ax.tick_params(axis="x", rotation=90)
ax.set_yticks(np.arange(len(cols)), cols)

plt.colorbar(ax_obj)
plt.show()

# %%
# 각 고객_교육수준에 대하여 고객_결혼여부별 고객_와인_구매금액의 평균을 히트맵으로 시각화
tmp = pd.pivot_table(df, index='고객_교육수준', columns='고객_결혼여부', values='고객_와인_구매금액', aggfunc='mean', fill_value = 0)
tmp
# Out:
# 고객_결혼여부          기혼          동거          미혼          사별          이혼
# 고객_교육수준
# 고졸       156.000000  185.757576  258.400000  192.000000  232.538462
# 박사       421.039370  425.191781  364.779661  575.545455  337.121212
# 석사       345.204545  302.410714  354.083333  404.250000  227.954545
# 초졸_중졸     21.384615    1.714286    3.428571    3.000000    0.000000
# 학사       270.504032  295.974026  256.741722  284.772727  305.071429

# %%
fig, ax = plt.subplots()
ax_obj = ax.matshow(tmp)
ax.set_xticks(np.arange(len(tmp.columns)), tmp.columns)
ax.set_yticks(np.arange(len(tmp.index)), tmp.index)

plt.colorbar(ax_obj)
plt.show()
